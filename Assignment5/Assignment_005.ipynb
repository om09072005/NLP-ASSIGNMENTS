# %%
import nltk
from nltk.corpus import wordnet
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
synonyms = []
for syn in wordnet.synsets("good"):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())

print(set(synonyms))
# Out:
# {'skilful', 'practiced', 'adept', 'estimable', 'in_effect', 'right', 'thoroughly', 'beneficial', 'upright', 'trade_good', 'undecomposed', 'honest', 'serious', 'near', 'proficient', 'skillful', 'commodity', 'dear', 'full', 'good', 'just', 'in_force', 'dependable', 'effective', 'secure', 'expert', 'unspoilt', 'honorable', 'salutary', 'soundly', 'goodness', 'safe', 'respectable', 'ripe', 'sound', 'well', 'unspoiled'}

# %%
synonyms = []
for syn in wordnet.synsets("good"):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())

print(set(synonyms))
# Out:
# {'skilful', 'practiced', 'adept', 'estimable', 'in_effect', 'right', 'thoroughly', 'beneficial', 'upright', 'trade_good', 'undecomposed', 'honest', 'serious', 'near', 'proficient', 'skillful', 'commodity', 'dear', 'full', 'good', 'just', 'in_force', 'dependable', 'effective', 'secure', 'expert', 'unspoilt', 'honorable', 'salutary', 'soundly', 'goodness', 'safe', 'respectable', 'ripe', 'sound', 'well', 'unspoiled'}

# %%
antonyms = []
for syn in wordnet.synsets("active"):
    for l in syn.lemmas():
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(antonyms))
# Out:
# {'quiet', 'dormant', 'passive', 'extinct', 'stative', 'passive_voice', 'inactive'}

# %%
syn = wordnet.synsets("chair")[0]
hypernyms = syn.hypernyms()

print([h.name() for h in hypernyms])
# Out:
# ['seat.n.03']

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')
print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091
